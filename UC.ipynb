# %%
import numpy as np
import pandas as pd

# %%
def acc(table):
    melodia_correct = 0
    melodia_incorrect = 0
    ritmo_correct = 0
    ritmo_incorrect = 0

    #table.iloc[:, 39]:  Response (AN)
    #table.iloc[:, 49]:  display (AX)
    #table.iloc[:, 50]:  desired answers (AY)


    for idx in range(len(table)):
    
        if table.iloc[idx, 39] == 'بله':

            if table.iloc[idx, 50] == 'Yes':

                if table.iloc[idx, 49] == 'Melodia':

                    melodia_correct = melodia_correct + 1
            
                if table.iloc[idx, 49] == 'Ritmo':

                    ritmo_correct = ritmo_correct +1
        

            if table.iloc[idx, 50] == 'No':

                if table.iloc[idx, 49] == 'Melodia':

                    melodia_incorrect = melodia_incorrect + 1

                if table.iloc[idx, 49] == 'Ritmo':

                    ritmo_incorrect = ritmo_incorrect + 1
    
        if table.iloc[idx, 39] == 'خیر' or table.iloc[idx, 39] == 'نه':

            if table.iloc[idx, 50] == 'No':

                if table.iloc[idx, 49] == 'Melodia':

                    melodia_correct = melodia_correct + 1

                if table.iloc[idx, 49] == 'Ritmo':

                  ritmo_correct = ritmo_correct + 1
        
            if table.iloc[idx, 50] == 'Yes':

                if table.iloc[idx, 49] == 'Melodia':

                    melodia_incorrect = melodia_incorrect + 1
            
                if table.iloc[idx, 49] == 'Ritmo':

                    ritmo_incorrect = ritmo_incorrect +1

    ritm_acc = 100 * ritmo_correct / (ritmo_correct + ritmo_incorrect)
    mel_acc = 100 * melodia_correct / (melodia_correct + melodia_incorrect)
    acc = 0.5 * (ritm_acc + mel_acc)
    verbose = True

    if verbose:
        print(f"correct instances of Ritmo: {ritmo_correct}")
        print(f"incorrect instances of Ritmo: {ritmo_incorrect}")
        print(f"correct instances of Melodia: {melodia_correct}")
        print(f"incorrect instances of Melodia: {melodia_incorrect}")
        print('----------------------')
        print(f"Ritmo accuracy: {ritm_acc}%")
        print(f"Melodia accuracy: {mel_acc}%")
        print(f"overall accuracy: {acc}")

# %%
lmao = pd.read_csv(r"New folder\5.csv", encoding='utf-8', header=None)
lmao.head()
# Out:
#             0              1                    2                3   \
# 0  Event Index  UTC Timestamp    UTC Date and Time  Local Timestamp
# 1            1  1693297702812  29/08/2023 08:28:22    1693294124563
# 2            2  1693297792696  29/08/2023 08:29:52    1693294214495
# 3            3  1693297802608  29/08/2023 08:30:02    1693294224225
# 4            4  1693297802864  29/08/2023 08:30:02    1693294224278
#
#                4                    5              6                   7   \
# 0  Local Timezone  Local Date and Time  Experiment ID  Experiment Version
# 1             3.5  29/08/2023 10:58:44              0                   0
# 2             3.5  29/08/2023 11:00:14              0                   0
# 3             3.5  29/08/2023 11:00:24              0                   0
# 4             3.5  29/08/2023 11:00:24              0                   0
#
#               8           9   ...         55         56               57  \
# 0  Tree Node Key  Repeat Key  ...  ritmo_par  timelimit  ShowProgressBar
# 1            NaN         NaN  ...        NaN        NaN              NaN
# 2            NaN         NaN  ...        NaN        NaN              NaN
# 3            NaN         NaN  ...        NaN        NaN              NaN
# 4            NaN         NaN  ...        NaN        NaN              NaN
#
#                                                   58  \
# 0          text_practice\r\n\r\nYour body text here.
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  In this case, the phrases were **identical**. ...
#
#                                                   59  \
# 0      text_practice\r\r\n\r\r\nYour body text here.
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  In this case, the phrases were **identical**. ...
#
#                                                   60  \
# 0  text_practice\r\r\r\n\r\r\r\nYour body text here.
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                   61  \
# 0  text_practice\r\r\r\r\n\r\r\r\r\nYour body tex...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  In this case, the phrases were **identical**. ...
#
#                                                   62  \
# 0  text_practice\r\r\r\r\r\n\r\r\r\r\r\nYour body...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  In this case, the phrases were **identical**. ...
#
#                                                   63              64
# 0  text_practice\r\r\r\r\r\r\n\r\r\r\r\r\r\nYour ...  CorrectanswerM
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4  In this case, the phrases were **identical**. ...             NaN
#
# [5 rows x 65 columns]

# %%
acc(lmao)
# Out:
# correct instances of Ritmo: 36
# incorrect instances of Ritmo: 13
# correct instances of Melodia: 34
# incorrect instances of Melodia: 18
# ----------------------
# Ritmo accuracy: 73.46938775510205%
# Melodia accuracy: 65.38461538461539%
# overall accuracy: 69.42700156985872

# %%
for i in table.iloc[:, 50]:
    if i == 'Yes':
        ritmo = ritmo + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\mhfar\OneDrive\Desktop\Depo\Code\UC\UC.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mhfar/OneDrive/Desktop/Depo/Code/UC/UC.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> for i in table.iloc[:, 50]:
#       <a href='vscode-notebook-cell:/c%3A/Users/mhfar/OneDrive/Desktop/Depo/Code/UC/UC.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a>     if i == 'Yes':
#       <a href='vscode-notebook-cell:/c%3A/Users/mhfar/OneDrive/Desktop/Depo/Code/UC/UC.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a>         ritmo = ritmo + 1
#
# NameError: name 'table' is not defined
